# %% [markdown]
# # Preparación de datos con Pandas

# %% [markdown]
# Autores: Ismael Sagredo Olivenza y Jorge Vindel Alfagame

# %% [markdown]
# ## Pandas

# %% [markdown]
# Pandas es el acrónimo de (Python Data Analysis Library) es un código fuente open source con licencia BSD que proporciona estructuras de datos, herramientas de análisis en python, fáciles de usar y de alto rendimiento.
#
# **Dataframe**
#
# Es la estuctura fundamental de Pandas. Es una especie de tabla que permite cargar información proveniente de un fichero y poder manejarla a nuestro antojo. Soporta importación directa desde csv lo que es muy útil ya que es el formato más extendido de los diferentes datasets que están publicados en internet.
# El dataframe puede tener en cada columna un tipo de datos diferentes.

# %% [markdown]
# Vamos a trabajar con Python para tener cierta soltura con el lenguaje antes realizar los laboratorios.
# Para ello vamos a realizar el siguiente ejercicios que consisten en trabajar con el datase de películas de movielens dataset que se puede descargar aquí:
# https://grouplens.org/datasets/movielens/
#
# Lo primero que haremos será cargar el fichero movies_metadata.csv usando Pandas en un dataframe.

# %%
import pandas as pd
import numpy as np
movies = pd.read_csv('movies_metadata.csv')
# Out:
# C:\Users\Jade\AppData\Local\Temp\ipykernel_13940\2008548134.py:3: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   movies = pd.read_csv('movies_metadata.csv')

# %% [markdown]
# El warning se produce porque hay algunos campos del dataset que son multicampo y no sabe de que tipo son. Vamos a establecer los tipos para que desaparezca el warning. Como nos indica que el campo que no conoce es el 10, establecemos el 10 como str.

# %%
movies = pd.read_csv('movies_metadata.csv',dtype={ 10 : 'str'})

# %% [markdown]
# Podemos visualizar el dataframe entero usando display. Pero en muchas ocasiones nos interesa mostrar solo una parte del dataframe para que podamos ver que pinta tiene el dataframe.

# %%
display(movies.head(n=4));
display(movies.tail(n=4));
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# 1                                   NaN   8844  tt0113497                en
# 2                                   NaN  15602  tt0113228                en
# 3                                   NaN  31357  tt0114885                en
#
#       original_title                                           overview  ...  \
# 0          Toy Story  Led by Woody, Andy's toys live happily in his ...  ...
# 1            Jumanji  When siblings Judy and Peter discover an encha...  ...
# 2   Grumpier Old Men  A family wedding reignites the ancient feud be...  ...
# 3  Waiting to Exhale  Cheated on, mistreated and stepped on, the wom...  ...
#
#   release_date      revenue runtime  \
# 0   1995-10-30  373554033.0    81.0
# 1   1995-12-15  262797249.0   104.0
# 2   1995-12-22          0.0   101.0
# 3   1995-12-22   81452156.0   127.0
#
#                                     spoken_languages    status  \
# 0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 2           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 3           [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                              tagline              title  \
# 0                                                NaN          Toy Story
# 1          Roll the dice and unleash the excitement!            Jumanji
# 2  Still Yelling. Still Fighting. Still Ready for...   Grumpier Old Men
# 3  Friends are the people who let you be yourself...  Waiting to Exhale
#
#    video vote_average vote_count
# 0  False          7.7     5415.0
# 1  False          6.9     2413.0
# 2  False          6.5       92.0
# 3  False          6.1       34.0
#
# [4 rows x 24 columns]
#        adult belongs_to_collection budget  \
# 45462  False                   NaN      0
# 45463  False                   NaN      0
# 45464  False                   NaN      0
# 45465  False                   NaN      0
#
#                                                   genres homepage      id  \
# 45462                      [{'id': 18, 'name': 'Drama'}]      NaN  111109
# 45463  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...      NaN   67758
# 45464                                                 []      NaN  227506
# 45465                                                 []      NaN  461257
#
#          imdb_id original_language       original_title  \
# 45462  tt2028550                tl  Siglo ng Pagluluwal
# 45463  tt0303758                en             Betrayal
# 45464  tt0008536                en  Satana likuyushchiy
# 45465  tt6980792                en             Queerama
#
#                                                 overview  ... release_date  \
# 45462  An artist struggles to finish his work while a...  ...   2011-11-17
# 45463  When one of her hits goes wrong, a professiona...  ...   2003-08-01
# 45464  In a small town live two brothers, one a minis...  ...   1917-10-21
# 45465  50 years after decriminalisation of homosexual...  ...   2017-06-09
#
#       revenue runtime                          spoken_languages    status  \
# 45462     0.0   360.0         [{'iso_639_1': 'tl', 'name': ''}]  Released
# 45463     0.0    90.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 45464     0.0    87.0                                        []  Released
# 45465     0.0    75.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                       tagline                title  video vote_average  \
# 45462                     NaN  Century of Birthing  False          9.0
# 45463  A deadly game of wits.             Betrayal  False          3.8
# 45464                     NaN     Satan Triumphant  False          0.0
# 45465                     NaN             Queerama  False          0.0
#
#       vote_count
# 45462        3.0
# 45463        6.0
# 45464        0.0
# 45465        0.0
#
# [4 rows x 24 columns]

# %% [markdown]
# Echamos un vistazo al dataframe, los principales campos que nos interesan son el id, el original_title, los géneros, pero también hay otros interesantes como el rating medio vote_ average.
#
# Ahora cargamos el fichero de ratings ratings_small.csv

# %%
ratings = pd.read_csv('ratings_small.csv')

# %%
display(ratings.head(n=4));
display(ratings.tail(n=4));
# Out:
#    userId  movieId  rating   timestamp
# 0       1       31     2.5  1260759144
# 1       1     1029     3.0  1260759179
# 2       1     1061     3.0  1260759182
# 3       1     1129     2.0  1260759185
#         userId  movieId  rating   timestamp
# 100002     671     6385     2.5  1070979663
# 100003     671     6565     3.5  1074784724
# 100004    5243     8587     1.0  1141800434
# 100005    8659     8587     3.0  1134949641

# %% [markdown]
# En el fichero rating tenemos las valoraciones de los usuarios identificados con un id anónimo (userId) y el identificador de la palícula (movieId). De esta forma podemos relacionar ambos dataframes. Por ejemplo, si queremos buscar todas las votaciones de una película concreta podemos extraer el id de la película que queremos buscar y con ese id consultar los ratings. Buscamos por ejemplo la película "The Lation King"

# %%
lion = movies[movies["title"] == "The Lion King"]
display(lion)
# Out:
#      adult                              belongs_to_collection    budget  \
# 359  False  {'id': 94032, 'name': 'The Lion King Collectio...  45000000
#
#                                                 genres  \
# 359  [{'id': 10751, 'name': 'Family'}, {'id': 16, '...
#
#                                    homepage    id    imdb_id  \
# 359  http://movies.disney.com/the-lion-king  8587  tt0110357
#
#     original_language original_title  \
# 359                en  The Lion King
#
#                                               overview  ... release_date  \
# 359  A young lion cub named Simba can't wait to be ...  ...   1994-06-23
#
#          revenue runtime                          spoken_languages    status  \
# 359  788241776.0    89.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                                tagline          title  video  \
# 359  Life's greatest adventure is finding your plac...  The Lion King  False
#
#     vote_average vote_count
# 359          8.0     5520.0
#
# [1 rows x 24 columns]

# %% [markdown]
# Pero buscar en un campo de texto de esta forma es complicado, ya que podemos estar buscando un texto y este no estar escrito exactamente igual que el almacenado (puedes poner una letra minúscula en alguna de las mayúsculas para comprobarlo). Una solución es buscar parcialmente. Pandas no lo permite hacer directamente, pero tenemos algunos trucos para conseguirlo, por ejemplo usando máscaras.

# %%
tested = 'lion king'
#Hacemos una subselección de los dos campos que nos interesan y los copiamos a otro dataframe
titles=movies[["original_title","id"]].copy();
# Nos creamos una máscara con el método applymap que nos indica que campos contienen una condición que establecemos mediante una lambda
mask = titles.applymap(lambda x:  tested.lower() in str(x).lower())
# Aplicamos la mascara para encontrar que campos nos interesan usando la función any
df1 = titles[mask.any(axis=1)]
#Any nos devuelve la fila o columna (dependiendo del axis) que al menos tenga un campo a true de la máscara. Axis 1 indica
# la columna en este caso. Si queremos devolver la fila, sería axis = 0
display(df1)
# Out:
# C:\Users\Jade\AppData\Local\Temp\ipykernel_13940\683699876.py:5: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   mask = titles.applymap(lambda x:  tested.lower() in str(x).lower())
#                       original_title     id
# 359                    The Lion King   8587
# 9115  The Lion King 2: Simba's Pride   9732
# 9353                The Lion King 1½  11430

# %% [markdown]
# Nos encuentra tres de las películas de de la saga de The Lion King. Ahora podemos identificar correctamente el criterio de búisqueda para seleccionar correctamente el que deseamos

# %%
lion = movies[movies["title"] == "The Lion King"]
display(lion)
# Out:
#      adult                              belongs_to_collection    budget  \
# 359  False  {'id': 94032, 'name': 'The Lion King Collectio...  45000000
#
#                                                 genres  \
# 359  [{'id': 10751, 'name': 'Family'}, {'id': 16, '...
#
#                                    homepage    id    imdb_id  \
# 359  http://movies.disney.com/the-lion-king  8587  tt0110357
#
#     original_language original_title  \
# 359                en  The Lion King
#
#                                               overview  ... release_date  \
# 359  A young lion cub named Simba can't wait to be ...  ...   1994-06-23
#
#          revenue runtime                          spoken_languages    status  \
# 359  788241776.0    89.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                                tagline          title  video  \
# 359  Life's greatest adventure is finding your plac...  The Lion King  False
#
#     vote_average vote_count
# 359          8.0     5520.0
#
# [1 rows x 24 columns]

# %% [markdown]
# Identificada la entrada de la película que queremos buscar, ahora procedemos, usando el ID a buscar los ratings de dicha película. Para acceder al valor del id tenemos que usar la función loc que define una selección a traves de un indice, en nuestro caso el 0 que nos devolverá la fila del índice.

# %%
lionId = int(lion["id"].loc[lion.index[0]])
#lionId = movies[movies["title"] == "The Lion King"]["id"]
print(lionId)
ratingLion = ratings[ratings["movieId"] == lionId]
display(ratingLion)
# Out:
# 8587
#         userId  movieId  rating   timestamp
# 100004    5243     8587     1.0  1141800434
# 100005    8659     8587     3.0  1134949641

# %% [markdown]
# Ahora queremos calcular la media de las valoraciones de la película en el fichero de ratings. Para ello vamos a ejecutar la función mean()

# %%
print(ratingLion["rating"].mean())
# Out:
# 2.0

# %% [markdown]
# Entre los campos vemos que hay un timestamp, vamos a convertirlo a date y le cambiamos el nombre a la columna

# %%
import datetime

ratings["timestamp"] = ratings["timestamp"].apply(lambda x:  datetime.datetime.fromtimestamp(x).isoformat())
ratings.rename(columns = {'timestamp':'datetime'}, inplace = True)
display(ratings)
# Out:
#         userId  movieId  rating             datetime
# 0            1       31     2.5  2009-12-14T03:52:24
# 1            1     1029     3.0  2009-12-14T03:52:59
# 2            1     1061     3.0  2009-12-14T03:53:02
# 3            1     1129     2.0  2009-12-14T03:53:05
# 4            1     1172     4.0  2009-12-14T03:53:25
# ...        ...      ...     ...                  ...
# 100001     671     6365     4.0  2003-12-09T04:26:03
# 100002     671     6385     2.5  2003-12-09T15:21:03
# 100003     671     6565     3.5  2004-01-22T16:18:44
# 100004    5243     8587     1.0  2006-03-08T07:47:14
# 100005    8659     8587     3.0  2005-12-19T00:47:21
#
# [100006 rows x 4 columns]

# %% [markdown]
# vamos a extraer el género de la película, lo primero que vemos es que los nombres estan con comillas simples, esto provoca un error en el parseo de json, asi que debemos primero limpiar la info usando replace()

# %%
genre = lion["genres"].loc[lion.index[0]];
genre = genre.replace("'", "\"")
import json
genreArray = json.loads(genre)
for g in genreArray:
    print(g["name"])
# Out:
# Family
# Animation
# Drama

# %% [markdown]
# Ahora vamos a aplicar una función que convierta los géneros en una cadena separada por comas para poder usarla en nuestras consultas más cómodamente. Para ello vamos a usar la función apply que nos permite aplicar una función a una fila o columna

# %%
def transform_genre(x):
    x = x.replace("'", "\"")
    xArr = json.loads(x)
    strOut = ""
    for g in xArr:
        strOut = strOut + g["name"] + ","
    strOut = strOut[0:-1]
    return strOut


movies["genres"] = movies["genres"].apply(transform_genre)

# %%
display(movies)
# Out:
#        adult                              belongs_to_collection    budget  \
# 0      False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1      False                                                NaN  65000000
# 2      False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3      False                                                NaN  16000000
# 4      False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...      ...                                                ...       ...
# 45461  False                                                NaN         0
# 45462  False                                                NaN         0
# 45463  False                                                NaN         0
# 45464  False                                                NaN         0
# 45465  False                                                NaN         0
#
#                          genres                              homepage      id  \
# 0       Animation,Comedy,Family  http://toystory.disney.com/toy-story     862
# 1      Adventure,Fantasy,Family                                   NaN    8844
# 2                Romance,Comedy                                   NaN   15602
# 3          Comedy,Drama,Romance                                   NaN   31357
# 4                        Comedy                                   NaN   11862
# ...                         ...                                   ...     ...
# 45461              Drama,Family  http://www.imdb.com/title/tt6209470/  439050
# 45462                     Drama                                   NaN  111109
# 45463     Action,Drama,Thriller                                   NaN   67758
# 45464                                                             NaN  227506
# 45465                                                             NaN  461257
#
#          imdb_id original_language               original_title  \
# 0      tt0114709                en                    Toy Story
# 1      tt0113497                en                      Jumanji
# 2      tt0113228                en             Grumpier Old Men
# 3      tt0114885                en            Waiting to Exhale
# 4      tt0113041                en  Father of the Bride Part II
# ...          ...               ...                          ...
# 45461  tt6209470                fa                      رگ خواب
# 45462  tt2028550                tl          Siglo ng Pagluluwal
# 45463  tt0303758                en                     Betrayal
# 45464  tt0008536                en          Satana likuyushchiy
# 45465  tt6980792                en                     Queerama
#
#                                                 overview  ... release_date  \
# 0      Led by Woody, Andy's toys live happily in his ...  ...   1995-10-30
# 1      When siblings Judy and Peter discover an encha...  ...   1995-12-15
# 2      A family wedding reignites the ancient feud be...  ...   1995-12-22
# 3      Cheated on, mistreated and stepped on, the wom...  ...   1995-12-22
# 4      Just when George Banks has recovered from his ...  ...   1995-02-10
# ...                                                  ...  ...          ...
# 45461        Rising and falling between a man and woman.  ...          NaN
# 45462  An artist struggles to finish his work while a...  ...   2011-11-17
# 45463  When one of her hits goes wrong, a professiona...  ...   2003-08-01
# 45464  In a small town live two brothers, one a minis...  ...   1917-10-21
# 45465  50 years after decriminalisation of homosexual...  ...   2017-06-09
#
#            revenue runtime                                   spoken_languages  \
# 0      373554033.0    81.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1      262797249.0   104.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 2              0.0   101.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 3       81452156.0   127.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 4       76578911.0   106.0           [{'iso_639_1': 'en', 'name': 'English'}]
# ...            ...     ...                                                ...
# 45461          0.0    90.0             [{'iso_639_1': 'fa', 'name': 'فارسی'}]
# 45462          0.0   360.0                  [{'iso_639_1': 'tl', 'name': ''}]
# 45463          0.0    90.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 45464          0.0    87.0                                                 []
# 45465          0.0    75.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#          status                                            tagline  \
# 0      Released                                                NaN
# 1      Released          Roll the dice and unleash the excitement!
# 2      Released  Still Yelling. Still Fighting. Still Ready for...
# 3      Released  Friends are the people who let you be yourself...
# 4      Released  Just When His World Is Back To Normal... He's ...
# ...         ...                                                ...
# 45461  Released         Rising and falling between a man and woman
# 45462  Released                                                NaN
# 45463  Released                             A deadly game of wits.
# 45464  Released                                                NaN
# 45465  Released                                                NaN
#
#                              title  video vote_average vote_count
# 0                        Toy Story  False          7.7     5415.0
# 1                          Jumanji  False          6.9     2413.0
# 2                 Grumpier Old Men  False          6.5       92.0
# 3                Waiting to Exhale  False          6.1       34.0
# 4      Father of the Bride Part II  False          5.7      173.0
# ...                            ...    ...          ...        ...
# 45461                       Subdue  False          4.0        1.0
# 45462          Century of Birthing  False          9.0        3.0
# 45463                     Betrayal  False          3.8        6.0
# 45464             Satan Triumphant  False          0.0        0.0
# 45465                     Queerama  False          0.0        0.0
#
# [45466 rows x 24 columns]

# %% [markdown]
# Ahora podemos buscar todas las películas de animación y por ejemplo calcular su puntuación media usando una máscara.

# %%
tested = "Animation"
maskGenre = movies.applymap(lambda x:  tested.lower() in str(x).lower())
animation = movies[maskGenre.any(axis=1)]
display(animation.head())
print(animation["vote_average"].mean())
# Out:
# C:\Users\Jade\AppData\Local\Temp\ipykernel_13940\2701463179.py:2: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   maskGenre = movies.applymap(lambda x:  tested.lower() in str(x).lower())
#      adult                              belongs_to_collection    budget  \
# 0    False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 12   False  {'id': 117693, 'name': 'Balto Collection', 'po...         0
# 47   False  {'id': 136214, 'name': 'Pocahontas Collection'...  55000000
# 235  False  {'id': 410261, 'name': 'A Goofy Movie Collecti...         0
# 240  False                                                NaN         0
#
#                                         genres  \
# 0                      Animation,Comedy,Family
# 12                  Family,Animation,Adventure
# 47            Adventure,Animation,Drama,Family
# 235  Romance,Animation,Family,Comedy,Adventure
# 240   Fantasy,Animation,Science Fiction,Family
#
#                                  homepage     id    imdb_id original_language  \
# 0    http://toystory.disney.com/toy-story    862  tt0114709                en
# 12                                    NaN  21032  tt0112453                en
# 47                                    NaN  10530  tt0114148                en
# 235                                   NaN  15789  tt0113198                en
# 240                                   NaN  43475  tt0113234                en
#
#        original_title                                           overview  ...  \
# 0           Toy Story  Led by Woody, Andy's toys live happily in his ...  ...
# 12              Balto  An outcast half-wolf risks his life to prevent...  ...
# 47         Pocahontas  History comes gloriously to life in Disney's e...  ...
# 235     A Goofy Movie  Though Goofy always means well, his amiable cl...  ...
# 240  Gumby: The Movie  The band is back together! Gumby reunites with...  ...
#
#     release_date      revenue runtime  \
# 0     1995-10-30  373554033.0    81.0
# 12    1995-12-22   11348324.0    78.0
# 47    1995-06-14  346079773.0    81.0
# 235   1995-04-07   35348597.0    78.0
# 240   1995-12-01          0.0    77.0
#
#                              spoken_languages    status  \
# 0    [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 12   [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 47   [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 235  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 240  [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                                tagline             title  \
# 0                                                  NaN         Toy Story
# 12                      Part Dog. Part Wolf. All Hero.             Balto
# 47                   An American legend comes to life.        Pocahontas
# 235  It's the story of a father who couldn't be clo...     A Goofy Movie
# 240                           The original green hero!  Gumby: The Movie
#
#      video vote_average vote_count
# 0    False          7.7     5415.0
# 12   False          7.1      423.0
# 47   False          6.7     1509.0
# 235  False          6.7      404.0
# 240  False          5.0        2.0
#
# [5 rows x 24 columns]
# 6.254214463840399

# %% [markdown]
# Ahora vamos a contar aquellas películas que tenían video y ver si son más que las que no lo tienen, para ello usamos groupby. Esta función agrupa por uno o varios campos, haciendo una especie de lista de colisiones para el resto de campos, de forma que podemos luego hacer preguntas sobre la lista.

# %%
numVideo = movies.groupby("video").count()
display(numVideo)
# Out:
#        adult  belongs_to_collection  budget  genres  homepage     id  imdb_id  \
# video
# False  45367                   4486   45367   45367      7750  45367    45350
# True      93                      4      93      93        28     93       93
#
#        original_language  original_title  overview  ...  production_countries  \
# video                                               ...
# False              45356           45367     44418  ...                 45367
# True                  93              93        88  ...                    93
#
#        release_date  revenue  runtime  spoken_languages  status  tagline  \
# video
# False         45287    45367    45111             45367   45286    20387
# True             89       93       92                93      93       25
#
#        title  vote_average  vote_count
# video
# False  45367         45367       45367
# True      93            93          93
#
# [2 rows x 23 columns]

# %% [markdown]
# Como vemos, la función count se aplica a todos los campos de la lista de colisión. Pero podemos aplicarlo a un campo concreto, al que nos interese, para que sea más óptimo. Por ejemplo vamos a calcular el runtime medio de las películas de video y las que no.

# %%
revenueVideo = movies.groupby("video")["runtime"].mean()
print(revenueVideo[revenueVideo.index[0]])
print(revenueVideo[revenueVideo.index[1]])
# Out:
# 94.14681563255083
# 85.0

# %% [markdown]
# Cargamos el fichero credits

# %%
credits = pd.read_csv('credits.csv')
display(credits.head())
# Out:
#                                                 cast  \
# 0  [{'cast_id': 14, 'character': 'Woody (voice)',...
# 1  [{'cast_id': 1, 'character': 'Alan Parrish', '...
# 2  [{'cast_id': 2, 'character': 'Max Goldman', 'c...
# 3  [{'cast_id': 1, 'character': "Savannah 'Vannah...
# 4  [{'cast_id': 1, 'character': 'George Banks', '...
#
#                                                 crew     id
# 0  [{'credit_id': '52fe4284c3a36847f8024f49', 'de...    862
# 1  [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...   8844
# 2  [{'credit_id': '52fe466a9251416c75077a89', 'de...  15602
# 3  [{'credit_id': '52fe44779251416c91011acb', 'de...  31357
# 4  [{'credit_id': '52fe44959251416c75039ed7', 'de...  11862

# %% [markdown]
# Y hacemos un merge entre movies y credits por el campo id. Si el campo id es int64 convertirlo a string

# %%
movies["id"] = movies["id"].astype(str)
credits["id"] = credits["id"].astype(str)
movie_credits = pd.merge(movies,credits,how='inner',on=('id'))
display(movie_credits)
# Out:
#        adult                              belongs_to_collection    budget  \
# 0      False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1      False                                                NaN  65000000
# 2      False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3      False                                                NaN  16000000
# 4      False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...      ...                                                ...       ...
# 45533  False                                                NaN         0
# 45534  False                                                NaN         0
# 45535  False                                                NaN         0
# 45536  False                                                NaN         0
# 45537  False                                                NaN         0
#
#                          genres                              homepage      id  \
# 0       Animation,Comedy,Family  http://toystory.disney.com/toy-story     862
# 1      Adventure,Fantasy,Family                                   NaN    8844
# 2                Romance,Comedy                                   NaN   15602
# 3          Comedy,Drama,Romance                                   NaN   31357
# 4                        Comedy                                   NaN   11862
# ...                         ...                                   ...     ...
# 45533              Drama,Family  http://www.imdb.com/title/tt6209470/  439050
# 45534                     Drama                                   NaN  111109
# 45535     Action,Drama,Thriller                                   NaN   67758
# 45536                                                             NaN  227506
# 45537                                                             NaN  461257
#
#          imdb_id original_language               original_title  \
# 0      tt0114709                en                    Toy Story
# 1      tt0113497                en                      Jumanji
# 2      tt0113228                en             Grumpier Old Men
# 3      tt0114885                en            Waiting to Exhale
# 4      tt0113041                en  Father of the Bride Part II
# ...          ...               ...                          ...
# 45533  tt6209470                fa                      رگ خواب
# 45534  tt2028550                tl          Siglo ng Pagluluwal
# 45535  tt0303758                en                     Betrayal
# 45536  tt0008536                en          Satana likuyushchiy
# 45537  tt6980792                en                     Queerama
#
#                                                 overview  ... runtime  \
# 0      Led by Woody, Andy's toys live happily in his ...  ...    81.0
# 1      When siblings Judy and Peter discover an encha...  ...   104.0
# 2      A family wedding reignites the ancient feud be...  ...   101.0
# 3      Cheated on, mistreated and stepped on, the wom...  ...   127.0
# 4      Just when George Banks has recovered from his ...  ...   106.0
# ...                                                  ...  ...     ...
# 45533        Rising and falling between a man and woman.  ...    90.0
# 45534  An artist struggles to finish his work while a...  ...   360.0
# 45535  When one of her hits goes wrong, a professiona...  ...    90.0
# 45536  In a small town live two brothers, one a minis...  ...    87.0
# 45537  50 years after decriminalisation of homosexual...  ...    75.0
#
#                                         spoken_languages    status  \
# 0               [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1      [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 2               [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 3               [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 4               [{'iso_639_1': 'en', 'name': 'English'}]  Released
# ...                                                  ...       ...
# 45533             [{'iso_639_1': 'fa', 'name': 'فارسی'}]  Released
# 45534                  [{'iso_639_1': 'tl', 'name': ''}]  Released
# 45535           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 45536                                                 []  Released
# 45537           [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                                  tagline  \
# 0                                                    NaN
# 1              Roll the dice and unleash the excitement!
# 2      Still Yelling. Still Fighting. Still Ready for...
# 3      Friends are the people who let you be yourself...
# 4      Just When His World Is Back To Normal... He's ...
# ...                                                  ...
# 45533         Rising and falling between a man and woman
# 45534                                                NaN
# 45535                             A deadly game of wits.
# 45536                                                NaN
# 45537                                                NaN
#
#                              title  video  vote_average vote_count  \
# 0                        Toy Story  False           7.7     5415.0
# 1                          Jumanji  False           6.9     2413.0
# 2                 Grumpier Old Men  False           6.5       92.0
# 3                Waiting to Exhale  False           6.1       34.0
# 4      Father of the Bride Part II  False           5.7      173.0
# ...                            ...    ...           ...        ...
# 45533                       Subdue  False           4.0        1.0
# 45534          Century of Birthing  False           9.0        3.0
# 45535                     Betrayal  False           3.8        6.0
# 45536             Satan Triumphant  False           0.0        0.0
# 45537                     Queerama  False           0.0        0.0
#
#                                                     cast  \
# 0      [{'cast_id': 14, 'character': 'Woody (voice)',...
# 1      [{'cast_id': 1, 'character': 'Alan Parrish', '...
# 2      [{'cast_id': 2, 'character': 'Max Goldman', 'c...
# 3      [{'cast_id': 1, 'character': "Savannah 'Vannah...
# 4      [{'cast_id': 1, 'character': 'George Banks', '...
# ...                                                  ...
# 45533  [{'cast_id': 0, 'character': '', 'credit_id': ...
# 45534  [{'cast_id': 1002, 'character': 'Sister Angela...
# 45535  [{'cast_id': 6, 'character': 'Emily Shaw', 'cr...
# 45536  [{'cast_id': 2, 'character': '', 'credit_id': ...
# 45537                                                 []
#
#                                                     crew
# 0      [{'credit_id': '52fe4284c3a36847f8024f49', 'de...
# 1      [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...
# 2      [{'credit_id': '52fe466a9251416c75077a89', 'de...
# 3      [{'credit_id': '52fe44779251416c91011acb', 'de...
# 4      [{'credit_id': '52fe44959251416c75039ed7', 'de...
# ...                                                  ...
# 45533  [{'credit_id': '5894a97d925141426c00818c', 'de...
# 45534  [{'credit_id': '52fe4af1c3a36847f81e9b15', 'de...
# 45535  [{'credit_id': '52fe4776c3a368484e0c8387', 'de...
# 45536  [{'credit_id': '533bccebc3a36844cf0011a7', 'de...
# 45537  [{'credit_id': '593e676c92514105b702e68e', 'de...
#
# [45538 rows x 26 columns]

# %% [markdown]
# Ahora podemos saber los actores de una película, pero tambien que películas ha hecho un actor.
# ## Ejercicio 01
# Buscar todas las películas interpretadas por **Bruce Willis**. Pero nos vamos a encontrar nuevamente con problemas en el json. Hay dos estrategias posibles, limpiar el json o ir al grano. Limpiar el json será costoso y dará bastantes problemas os proponemos la segunda opción:
# Hay que crear una función que convierta Json a array por espacios. La función anterior no nos vale porque este json tiene errores que hay que subsanar más allá de convertir comillas simples por dobles (por ejemplo algunos campos tiene comillas simples en el interior del campo), por lo que es mejor ir directamente a procesar los campos name: <nombre del actor> extraerlos y contruir una lista sin usar el parser de json.
#
# NOTA: Esto es muy típico en los datasets, no todos los datos vienen limpios y gran parte del trabajo en IA en general y Machine Learning en particular es preprocesar los datos paraque nos sean útiles.

# %%
def dame_actores(texto):
    actores = []
    partes = texto.split("'name': '") # Creo un array de actores para cada pelicula

    for parte in partes[1:]:
        nombre = parte.split("'")[0] # Parto el texto en trozos donde empieza cada nombre
        actores.append(nombre)

    return actores

movie_credits['actors_clean'] = movie_credits['cast'].apply(dame_actores) # De todas las peliculas, saco los actores que salen en cada una

pelis_bruce = movie_credits[movie_credits['actors_clean'].apply(lambda x: "Bruce Willis" in x)] # Busco aquellas pelis donde salga Bruce Willis

display(pelis_bruce[['original_title', 'actors_clean']].head()) # Muestro las peliculas filtradas
# Out:
#                  original_title  \
# 17                   Four Rooms
# 31               Twelve Monkeys
# 162  Die Hard: With a Vengeance
# 277               Nobody's Fool
# 292                Pulp Fiction
#
#                                           actors_clean
# 17   [Tim Roth, Antonio Banderas, Jennifer Beals, M...
# 31   [Bruce Willis, Madeleine Stowe, Brad Pitt, Chr...
# 162  [Bruce Willis, Jeremy Irons, Samuel L. Jackson...
# 277  [Paul Newman, Bruce Willis, Melanie Griffith, ...
# 292  [John Travolta, Samuel L. Jackson, Uma Thurman...

# %% [markdown]
# Vamos a filtrar todas las películas de animación que tienen homepage y vamos a crearnos un dataframe manualmente con tres columnas, el id de la película, el título y el homepage y generaremos un número aleatorio . Después, escribiremos el dataframe como csv.

# %%
AnimationHomepage = animation[animation["homepage"].notnull()]
display(AnimationHomepage)
NewAnimationHomepage = pd.DataFrame({'id':AnimationHomepage['id'],
                          'homepage':AnimationHomepage["homepage"],
                          'title':AnimationHomepage["title"]})
# Out:
#        adult                              belongs_to_collection    budget  \
# 0      False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 309    False  {'id': 144200, 'name': 'Swan Princess Series',...  35000000
# 359    False  {'id': 94032, 'name': 'The Lion King Collectio...  45000000
# 581    False  {'id': 86027, 'name': 'Aladdin Collection', 'p...  28000000
# 587    False                                                NaN   1488423
# ...      ...                                                ...       ...
# 45098  False                                                NaN      2000
# 45139  False                                                NaN  50000000
# 45156  False                                                NaN         0
# 45172  False                                                NaN         0
# 45270  False                                                NaN         0
#
#                                                   genres  \
# 0                                Animation,Comedy,Family
# 309                                            Animation
# 359                               Family,Animation,Drama
# 581    Animation,Family,Comedy,Adventure,Fantasy,Romance
# 587                             Fantasy,Animation,Family
# ...                                                  ...
# 45098                                   Animation,Horror
# 45139                            Comedy,Family,Animation
# 45156                             Animation,Horror,Drama
# 45172                                          Animation
# 45270                                          Animation
#
#                                                 homepage      id    imdb_id  \
# 0                   http://toystory.disney.com/toy-story     862  tt0114709
# 309    http://www.sonypictures.com/movies/theswanprin...   22586  tt0111333
# 359               http://movies.disney.com/the-lion-king    8587  tt0110357
# 581                     http://movies.disney.com/aladdin     812  tt0103639
# 587    http://movies.disney.com/snow-white-and-the-se...     408  tt0029583
# ...                                                  ...     ...        ...
# 45098      http://www.pixelnitrate.com/sebastians_voodoo   52803  tt1305751
# 45139                     http://www.theemoji-movie.com/  378236  tt4877122
# 45156  http://www.embrace-the-weird.com/Enchiridion-M...  366071  tt2279314
# 45172                         https://vimeo.com/18603661  351423  tt1557200
# 45270                          https://www.pixar.com/lou  433471  tt6267732
#
#       original_language                   original_title  \
# 0                    en                        Toy Story
# 309                  en                The Swan Princess
# 359                  en                    The Lion King
# 581                  en                          Aladdin
# 587                  en  Snow White and the Seven Dwarfs
# ...                 ...                              ...
# 45098                en               Sebastian's Voodoo
# 45139                en                  The Emoji Movie
# 45156                en                      Enchiridion
# 45172                en       Dock Ellis & The LSD No-No
# 45270                en                              Lou
#
#                                                 overview  ... release_date  \
# 0      Led by Woody, Andy's toys live happily in his ...  ...   1995-10-30
# 309    The beautiful princess Odette is transformed i...  ...   1994-11-18
# 359    A young lion cub named Simba can't wait to be ...  ...   1994-06-23
# 581    Princess Jasmine grows tired of being forced t...  ...   1992-11-25
# 587    A beautiful girl, Snow White, takes refuge in ...  ...   1937-12-20
# ...                                                  ...  ...          ...
# 45098  A voodoo doll must find the courage to save hi...  ...   2008-06-07
# 45139  Gene, a multi-expressional emoji, sets out on ...  ...   2017-07-28
# 45156  A priest is recruited by federal marshals to h...  ...   2012-10-12
# 45172  In 2008, a year before the great Dock Ellis di...  ...   2010-06-01
# 45270  A Pixar short about a lost-and-found box and t...  ...   2017-06-16
#
#            revenue runtime                              spoken_languages  \
# 0      373554033.0    81.0      [{'iso_639_1': 'en', 'name': 'English'}]
# 309      9771658.0    89.0      [{'iso_639_1': 'en', 'name': 'English'}]
# 359    788241776.0    89.0      [{'iso_639_1': 'en', 'name': 'English'}]
# 581    504050219.0    90.0      [{'iso_639_1': 'en', 'name': 'English'}]
# 587    184925486.0    83.0      [{'iso_639_1': 'en', 'name': 'English'}]
# ...            ...     ...                                           ...
# 45098          0.0     4.0  [{'iso_639_1': 'xx', 'name': 'No Language'}]
# 45139   66913939.0    86.0      [{'iso_639_1': 'en', 'name': 'English'}]
# 45156          0.0    81.0      [{'iso_639_1': 'en', 'name': 'English'}]
# 45172          0.0     5.0      [{'iso_639_1': 'en', 'name': 'English'}]
# 45270          0.0     6.0      [{'iso_639_1': 'en', 'name': 'English'}]
#
#          status                                            tagline  \
# 0      Released                                                NaN
# 309    Released  An enchanting classic destined to capture your...
# 359    Released  Life's greatest adventure is finding your plac...
# 581    Released                                      Wish granted!
# 587    Released  The Happiest, Dopiest, Grumpiest, Sneeziest mo...
# ...         ...                                                ...
# 45098  Released                                                NaN
# 45139  Released                                 Not easy being meh
# 45156  Released                               Embrace the weird...
# 45172  Released                                                NaN
# 45270  Released                                                NaN
#
#                                  title  video vote_average vote_count
# 0                            Toy Story  False          7.7     5415.0
# 309                  The Swan Princess  False          6.5      251.0
# 359                      The Lion King  False          8.0     5520.0
# 581                            Aladdin  False          7.4     3495.0
# 587    Snow White and the Seven Dwarfs  False          6.9     1973.0
# ...                                ...    ...          ...        ...
# 45098               Sebastian's Voodoo  False          6.8       18.0
# 45139                  The Emoji Movie  False          5.8      327.0
# 45156                      Enchiridion  False          0.0        0.0
# 45172       Dock Ellis & The LSD No-No  False          9.0        1.0
# 45270                              Lou  False          8.5       17.0
#
# [588 rows x 24 columns]

# %% [markdown]
# Escribimos el dataframe

# %%
NewAnimationHomepage.to_csv("NewAnimationHomepage.csv",index=False)

# %% [markdown]
# ## Uso de sklearn para calcular una regresión lineal

# %% [markdown]
# Sklearn es la libreria principal que vamos a utilizar para aplicar técnicas
# de aprendizaje máquina. Pero despone de multitud de herramientas que son útiles
# Por ejemplo dispone de regresión lineal.
#
# Vamos a optener la ecuación lineal que minimiza el error cuadrático medio.
# Esta ecuación constará de una variable dependiente y un conjunto de variables
# independientes.
#
# Para cada x se optendrá un error concreto en función de la distancia existente
# entre el punto marcado por la recta y el valor real.

# %%
import numpy as np
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score
#cargando el dataset de diabetes que incorpora sklearn.
diabetes = datasets.load_diabetes()
#usamos solo una caracteristica
diabetes_x = diabetes.data[:,np.newaxis,2]
#dividimos el dato ente entrenamiento y validación o test.
#esto es algo recurrente cuando hacemos aprendizaje máquina.

diabetes_x_train = diabetes_x[:-20] # Todos menos los 20 ultimos.

diabetes_x_test = diabetes_x[-20:] # desde el puesto 10 empezanod por le final hasta el final

# luego cogemos las clases para obtener los valores esperados.
diabetes_y_train = diabetes.target[:-20]
diabetes_y_test = diabetes.target[-20:]

#creamos la regresión lineal:
linearreg = linear_model.LinearRegression()
linearreg.fit(diabetes_x_train, diabetes_y_train)

#Comprobamos la capacidad de predicción
diabetes_y_pred = linearreg.predict(diabetes_x_test)
print("Mostramos los valores obtenidos por la regresión lineal")
print('Coeficientes: \n', linearreg.coef_)
print("MSE: %.2f"
      % mean_squared_error(diabetes_y_test, diabetes_y_pred))
print('R2: %.2f' % r2_score(diabetes_y_test, diabetes_y_pred)) #coeficiente de regresión.
# Out:
# Mostramos los valores obtenidos por la regresión lineal
# Coeficientes:
#  [938.23786125]
# MSE: 2548.07
# R2: 0.47

# %% [markdown]
# Ahora dibujamos una gráfica usando matplotlib.pyplot que muestre la matriz de puntos y al recta de regresión.

# %%
import matplotlib.pyplot as plt
plt.scatter(diabetes_x_test, diabetes_y_test,  color='black')
plt.plot(diabetes_x_test, diabetes_y_pred, color='blue', linewidth=3) #en linewidth le indicamos la linea en la gráfica.
plt.xticks(())
plt.yticks(())

plt.show()

# %% [markdown]
# # Ejercicio 02
# Realiza otra recta de regresión del dataset "Boston" (Boston house prices) que tambien podeis encontrar en sklearn, pintando su gráfica.

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.datasets import fetch_california_housing

california = fetch_california_housing()
california_x = california.data[:, np.newaxis, 0]
california_y = california.target[:]

california_x_train = california_x[:-500]
california_x_test = california_x[-500:]

california_y_train = california.target[:-500]
california_y_test = california.target[-500:]

regr_california = linear_model.LinearRegression()
regr_california.fit(california_x_train, california_y_train)

california_y_pred = regr_california.predict(california_x_test)

print("Mostramos los valores obtenidos por la regresión lineal")
print('Coeficientes: \n', regr_california.coef_)
print("MSE: %.2f"
      % mean_squared_error(california_y_test, california_y_pred))
print('R2: %.2f' % r2_score(california_y_test, california_y_pred)) #coeficiente de regresión.

plt.scatter(california_x_test, california_y_test,  color='black')
plt.plot(california_x_test, california_y_pred, color='blue', linewidth=3)

plt.xlabel("Ingresos medios (en decenas de miles de $)")
plt.ylabel("Precio de la vivienda ($)")
plt.title("Prediccion de precios de las viviendas en Californa en funcion de las habitaciones")


plt.xticks(())
plt.yticks(())

plt.show()
# Out:
# Mostramos los valores obtenidos por la regresión lineal
# Coeficientes:
#  [0.41787357]
# MSE: 0.44
# R2: 0.64

# %% [markdown]
# # Ejercicio 03
# Basándote en datos aleatorios (los que quieras) crea un gráfico de tarta (pie chart) con Mapplotlib. La gráfica debe tener un título, etiquetas de cada clase, visible los porcentajes de cada clase y opcionalmente una de las clases resaltadas.

# %%
# Ejercicio 3: Gráfico de tarta con datos aleatorios

import matplotlib.pyplot as plt
import numpy as np

np.random.seed(42) #Ponemos un numeor para que sea reproducible, quitamos seed() si no lo queremos

categorias = ['Acción', 'Comedia', 'Drama', 'Ciencia Ficción', 'Terror']

# Generamos porcentajes aleatorios que sumen 100
porcentajes = np.random.dirichlet(np.ones(len(categorias))) * 100

# Creamos el gráfico de tarta
plt.figure(figsize=(6, 6)) #Crea tamaño de fondo
plt.pie(porcentajes, 
        labels=categorias, 
        autopct='%1.1f%%',      # Muestra porcentajes con un decimal
)           

# Título del gráfico
plt.title('Distribución de géneros cinematográficos ', 
          fontsize=16, fontweight='bold')

# Asegura que el círculo sea perfecto
plt.axis('equal')

# Mostramos el gráfico
plt.show()
